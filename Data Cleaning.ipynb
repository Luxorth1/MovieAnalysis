# %%
#import necessary packages for data cleaning
import pandas as pd
import numpy as np

# %%
#loading in the main data set from https://datasets.imdbws.com/
df = pd.read_csv('title.basics.tsv', delimiter='\t', low_memory=False)

# %%
#preview df to ensure that data was brought in properly
df.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#    isAdult startYear endYear runtimeMinutes                    genres
# 0        0      1894      \N              1         Documentary,Short
# 1        0      1892      \N              5           Animation,Short
# 2        0      1892      \N              4  Animation,Comedy,Romance
# 3        0      1892      \N             12           Animation,Short
# 4        0      1893      \N              1              Comedy,Short

# %%
#analyze the length of df
len(df)
# Out:
# 6721152

# %%
#create a new df with nothing but the titleType movie
dfMovie = df[(df['titleType'] == 'movie')]

# %%
#preview of dfMovie
dfMovie.head()
# Out:
#         tconst titleType                   primaryTitle  \
# 8    tt0000009     movie                     Miss Jerry
# 145  tt0000147     movie  The Corbett-Fitzsimmons Fight
# 332  tt0000335     movie          Soldiers of the Cross
# 499  tt0000502     movie                       Bohemios
# 571  tt0000574     movie    The Story of the Kelly Gang
#
#                      originalTitle  isAdult startYear endYear runtimeMinutes  \
# 8                       Miss Jerry        0      1894      \N             45
# 145  The Corbett-Fitzsimmons Fight        0      1897      \N             20
# 332          Soldiers of the Cross        0      1900      \N             \N
# 499                       Bohemios        0      1905      \N            100
# 571    The Story of the Kelly Gang        0      1906      \N             70
#
#                      genres
# 8                   Romance
# 145  Documentary,News,Sport
# 332         Biography,Drama
# 499                      \N
# 571   Biography,Crime,Drama

# %%
#additional preview of dfMovie
dfMovie.info()
print(len(dfMovie))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 548292 entries, 8 to 6721102
# Data columns (total 9 columns):
# tconst            548292 non-null object
# titleType         548292 non-null object
# primaryTitle      548292 non-null object
# originalTitle     548292 non-null object
# isAdult           548292 non-null int64
# startYear         548292 non-null object
# endYear           548292 non-null object
# runtimeMinutes    548292 non-null object
# genres            548292 non-null object
# dtypes: int64(1), object(8)
# memory usage: 41.8+ MB
# 548292

# %%
#need to convert startYear as integers to narrow down data set to movies released in 2005-2020
dfMovie['startYear'].dropna()
# Out:
# 8          1894
# 145        1897
# 332        1900
# 499        1905
# 571        1906
#            ...
# 6721041    2015
# 6721068    2007
# 6721080    2013
# 6721091    2017
# 6721102    2013
# Name: startYear, Length: 548292, dtype: object

# %%
#drop rows with placeholder values
dfMovie = dfMovie[(dfMovie['startYear'] != '\\N')]

# %%
#Preview changes to dfMovie
dfMovie.head()
# Out:
#         tconst titleType                   primaryTitle  \
# 8    tt0000009     movie                     Miss Jerry
# 145  tt0000147     movie  The Corbett-Fitzsimmons Fight
# 332  tt0000335     movie          Soldiers of the Cross
# 499  tt0000502     movie                       Bohemios
# 571  tt0000574     movie    The Story of the Kelly Gang
#
#                      originalTitle  isAdult startYear endYear runtimeMinutes  \
# 8                       Miss Jerry        0      1894      \N             45
# 145  The Corbett-Fitzsimmons Fight        0      1897      \N             20
# 332          Soldiers of the Cross        0      1900      \N             \N
# 499                       Bohemios        0      1905      \N            100
# 571    The Story of the Kelly Gang        0      1906      \N             70
#
#                      genres
# 8                   Romance
# 145  Documentary,News,Sport
# 332         Biography,Drama
# 499                      \N
# 571   Biography,Crime,Drama

# %%
#change all values to integers
dfMovie.startYear = dfMovie.startYear.astype('int32', copy=False)

# %%
#verify change 
dfMovie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 485061 entries, 8 to 6721102
# Data columns (total 9 columns):
# tconst            485061 non-null object
# titleType         485061 non-null object
# primaryTitle      485061 non-null object
# originalTitle     485061 non-null object
# isAdult           485061 non-null int64
# startYear         485061 non-null int32
# endYear           485061 non-null object
# runtimeMinutes    485061 non-null object
# genres            485061 non-null object
# dtypes: int32(1), int64(1), object(7)
# memory usage: 35.2+ MB

# %%
#Narrow dataset to only include movies within desired dates
dfMovie = dfMovie[(dfMovie['startYear'] >= 2005) & (dfMovie['startYear'] <= 2020)]

# %%
#ensure there are no values I do not want
dfMovie.startYear.unique()
# Out:
# array([2014, 2020, 2010, 2018, 2005, 2017, 2006, 2008, 2019, 2007, 2009,
#        2012, 2013, 2011, 2015, 2016])

# %%
#export dfMovie to a CSV for future work
dfMovie.to_csv('movie.csv', index=False)

# %%
#this ensures that there are no duplicate values within the df
dfMovie.duplicated(keep='first').unique()
# Out:
# array([False])

# %%
#here we will reload our csv file for additional work.
dfMaster = pd.read_csv('movie.csv', low_memory=False)

# %%
dfMaster.head()
# Out:
#       tconst titleType                               primaryTitle  \
# 0  tt0016906     movie                                 Frivolinas
# 1  tt0062336     movie  El tango del viudo y su espejo deformante
# 2  tt0064322     movie                   The Woman with the Knife
# 3  tt0069049     movie                 The Other Side of the Wind
# 4  tt0069204     movie                            Sabse Bada Sukh
#
#                                originalTitle  isAdult  startYear endYear  \
# 0                                 Frivolinas        0       2014      \N
# 1  El tango del viudo y su espejo deformante        0       2020      \N
# 2                        La femme au couteau        0       2010      \N
# 3                 The Other Side of the Wind        0       2018      \N
# 4                            Sabse Bada Sukh        0       2018      \N
#
#   runtimeMinutes          genres
# 0             80  Comedy,Musical
# 1             70           Drama
# 2             80  Drama,Thriller
# 3            122           Drama
# 4             \N    Comedy,Drama

# %%
#here we will drop the endYear table as it is not necessary to have.
dfMaster.drop(columns = 'endYear')
# Out:
#            tconst titleType  \
# 0       tt0016906     movie
# 1       tt0062336     movie
# 2       tt0064322     movie
# 3       tt0069049     movie
# 4       tt0069204     movie
# ...           ...       ...
# 209201  tt9916622     movie
# 209202  tt9916680     movie
# 209203  tt9916706     movie
# 209204  tt9916730     movie
# 209205  tt9916754     movie
#
#                                              primaryTitle  \
# 0                                              Frivolinas
# 1               El tango del viudo y su espejo deformante
# 2                                The Woman with the Knife
# 3                              The Other Side of the Wind
# 4                                         Sabse Bada Sukh
# ...                                                   ...
# 209201        Rodolpho Teóphilo - O Legado de um Pioneiro
# 209202  De la ilusión al desconcierto: cine colombiano...
# 209203                                    Dankyavar Danka
# 209204                                             6 Gunn
# 209205                     Chico Albuquerque - Revelações
#
#                                             originalTitle  isAdult  startYear  \
# 0                                              Frivolinas        0       2014
# 1               El tango del viudo y su espejo deformante        0       2020
# 2                                     La femme au couteau        0       2010
# 3                              The Other Side of the Wind        0       2018
# 4                                         Sabse Bada Sukh        0       2018
# ...                                                   ...      ...        ...
# 209201        Rodolpho Teóphilo - O Legado de um Pioneiro        0       2015
# 209202  De la ilusión al desconcierto: cine colombiano...        0       2007
# 209203                                    Dankyavar Danka        0       2013
# 209204                                             6 Gunn        0       2017
# 209205                     Chico Albuquerque - Revelações        0       2013
#
#        runtimeMinutes          genres
# 0                  80  Comedy,Musical
# 1                  70           Drama
# 2                  80  Drama,Thriller
# 3                 122           Drama
# 4                  \N    Comedy,Drama
# ...               ...             ...
# 209201             57     Documentary
# 209202            100     Documentary
# 209203             \N          Comedy
# 209204            116              \N
# 209205             49     Documentary
#
# [209206 rows x 8 columns]

# %%
#here we will begin to process additional data
dfWritersDir = pd.read_csv('title.crew.tsv', delimiter = '\t', low_memory=False)

# %%
dfWritersDir.tail()
# Out:
#             tconst            directors                        writers
# 6724395  tt9916848  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377
# 6724396  tt9916850  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377
# 6724397  tt9916852  nm5519375,nm5519454  nm6182221,nm1628284,nm2921377
# 6724398  tt9916856           nm10538645                      nm6951431
# 6724399  tt9916880            nm0996406            nm1482639,nm2586970

# %%
dfNames = pd.read_csv('name.basics.tsv', delimiter = '\t', low_memory=False)

# %%
dfNames.head()
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934        \N
# 3  nm0000004     John Belushi      1949      1982
# 4  nm0000005   Ingmar Bergman      1918      2007
#
#                 primaryProfession                           knownForTitles
# 0  soundtrack,actor,miscellaneous  tt0043044,tt0050419,tt0053137,tt0072308
# 1              actress,soundtrack  tt0037382,tt0038355,tt0117057,tt0071877
# 2     actress,soundtrack,producer  tt0054452,tt0059956,tt0057345,tt0049189
# 3         actor,soundtrack,writer  tt0078723,tt0080455,tt0077975,tt0072562
# 4           writer,director,actor  tt0050976,tt0083922,tt0060827,tt0050986

# %%
dfMaster.set_index('tconst')
# Out:
#           titleType                                       primaryTitle  \
# tconst
# tt0016906     movie                                         Frivolinas
# tt0062336     movie          El tango del viudo y su espejo deformante
# tt0064322     movie                           The Woman with the Knife
# tt0069049     movie                         The Other Side of the Wind
# tt0069204     movie                                    Sabse Bada Sukh
# ...             ...                                                ...
# tt9916622     movie        Rodolpho Teóphilo - O Legado de um Pioneiro
# tt9916680     movie  De la ilusión al desconcierto: cine colombiano...
# tt9916706     movie                                    Dankyavar Danka
# tt9916730     movie                                             6 Gunn
# tt9916754     movie                     Chico Albuquerque - Revelações
#
#                                                originalTitle  isAdult  \
# tconst
# tt0016906                                         Frivolinas        0
# tt0062336          El tango del viudo y su espejo deformante        0
# tt0064322                                La femme au couteau        0
# tt0069049                         The Other Side of the Wind        0
# tt0069204                                    Sabse Bada Sukh        0
# ...                                                      ...      ...
# tt9916622        Rodolpho Teóphilo - O Legado de um Pioneiro        0
# tt9916680  De la ilusión al desconcierto: cine colombiano...        0
# tt9916706                                    Dankyavar Danka        0
# tt9916730                                             6 Gunn        0
# tt9916754                     Chico Albuquerque - Revelações        0
#
#            startYear endYear runtimeMinutes          genres
# tconst
# tt0016906       2014      \N             80  Comedy,Musical
# tt0062336       2020      \N             70           Drama
# tt0064322       2010      \N             80  Drama,Thriller
# tt0069049       2018      \N            122           Drama
# tt0069204       2018      \N             \N    Comedy,Drama
# ...              ...     ...            ...             ...
# tt9916622       2015      \N             57     Documentary
# tt9916680       2007      \N            100     Documentary
# tt9916706       2013      \N             \N          Comedy
# tt9916730       2017      \N            116              \N
# tt9916754       2013      \N             49     Documentary
#
# [209206 rows x 8 columns]

# %%
dfWritersDir.set_index('tconst')
# Out:
#                      directors                        writers
# tconst
# tt0000001            nm0005690                             \N
# tt0000002            nm0721526                             \N
# tt0000003            nm0721526                             \N
# tt0000004            nm0721526                             \N
# tt0000005            nm0005690                             \N
# ...                        ...                            ...
# tt9916848  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377
# tt9916850  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377
# tt9916852  nm5519375,nm5519454  nm6182221,nm1628284,nm2921377
# tt9916856           nm10538645                      nm6951431
# tt9916880            nm0996406            nm1482639,nm2586970
#
# [6724400 rows x 2 columns]

# %%
dfMaster = dfMaster.merge(dfWritersDir,on='tconst',how='left')

# %%
dfMaster.head()
# Out:
#       tconst titleType                               primaryTitle  \
# 0  tt0016906     movie                                 Frivolinas
# 1  tt0062336     movie  El tango del viudo y su espejo deformante
# 2  tt0064322     movie                   The Woman with the Knife
# 3  tt0069049     movie                 The Other Side of the Wind
# 4  tt0069204     movie                            Sabse Bada Sukh
#
#                                originalTitle  isAdult  startYear endYear  \
# 0                                 Frivolinas        0       2014      \N
# 1  El tango del viudo y su espejo deformante        0       2020      \N
# 2                        La femme au couteau        0       2010      \N
# 3                 The Other Side of the Wind        0       2018      \N
# 4                            Sabse Bada Sukh        0       2018      \N
#
#   runtimeMinutes          genres            directors              writers
# 0             80  Comedy,Musical            nm0136068                   \N
# 1             70           Drama  nm0749914,nm0765384  nm0749914,nm1146177
# 2             80  Drama,Thriller            nm0863604            nm0863604
# 3            122           Drama            nm0000080  nm0000080,nm0462648
# 4             \N    Comedy,Drama            nm0611531            nm0347899

# %%
dfMaster.drop(columns='endYear')
# Out:
#            tconst titleType  \
# 0       tt0016906     movie
# 1       tt0062336     movie
# 2       tt0064322     movie
# 3       tt0069049     movie
# 4       tt0069204     movie
# ...           ...       ...
# 209201  tt9916622     movie
# 209202  tt9916680     movie
# 209203  tt9916706     movie
# 209204  tt9916730     movie
# 209205  tt9916754     movie
#
#                                              primaryTitle  \
# 0                                              Frivolinas
# 1               El tango del viudo y su espejo deformante
# 2                                The Woman with the Knife
# 3                              The Other Side of the Wind
# 4                                         Sabse Bada Sukh
# ...                                                   ...
# 209201        Rodolpho Teóphilo - O Legado de um Pioneiro
# 209202  De la ilusión al desconcierto: cine colombiano...
# 209203                                    Dankyavar Danka
# 209204                                             6 Gunn
# 209205                     Chico Albuquerque - Revelações
#
#                                             originalTitle  isAdult  startYear  \
# 0                                              Frivolinas        0       2014
# 1               El tango del viudo y su espejo deformante        0       2020
# 2                                     La femme au couteau        0       2010
# 3                              The Other Side of the Wind        0       2018
# 4                                         Sabse Bada Sukh        0       2018
# ...                                                   ...      ...        ...
# 209201        Rodolpho Teóphilo - O Legado de um Pioneiro        0       2015
# 209202  De la ilusión al desconcierto: cine colombiano...        0       2007
# 209203                                    Dankyavar Danka        0       2013
# 209204                                             6 Gunn        0       2017
# 209205                     Chico Albuquerque - Revelações        0       2013
#
#        runtimeMinutes          genres            directors  \
# 0                  80  Comedy,Musical            nm0136068
# 1                  70           Drama  nm0749914,nm0765384
# 2                  80  Drama,Thriller            nm0863604
# 3                 122           Drama            nm0000080
# 4                  \N    Comedy,Drama            nm0611531
# ...               ...             ...                  ...
# 209201             57     Documentary  nm9272491,nm9272490
# 209202            100     Documentary            nm0652213
# 209203             \N          Comedy            nm7764440
# 209204            116              \N           nm10538612
# 209205             49     Documentary  nm9272490,nm8349149
#
#                      writers
# 0                         \N
# 1        nm0749914,nm1146177
# 2                  nm0863604
# 3        nm0000080,nm0462648
# 4                  nm0347899
# ...                      ...
# 209201   nm9272490,nm9272491
# 209202  nm0652213,nm10538576
# 209203             nm7933903
# 209204            nm10538612
# 209205   nm8349149,nm9272490
#
# [209206 rows x 10 columns]

# %%
dfMaster = dfMaster[(dfMaster['genres'] !=r'\N')]

# %%
dfMaster  = dfMaster.drop(columns = 'endYear')

# %%
dfMaster  = dfMaster.drop(columns = 'primaryTitle')

# %%
dfMaster.head()
# Out:
#       tconst titleType                              originalTitle  isAdult  \
# 0  tt0016906     movie                                 Frivolinas        0
# 1  tt0062336     movie  El tango del viudo y su espejo deformante        0
# 2  tt0064322     movie                        La femme au couteau        0
# 3  tt0069049     movie                 The Other Side of the Wind        0
# 4  tt0069204     movie                            Sabse Bada Sukh        0
#
#    startYear runtimeMinutes          genres            directors  \
# 0       2014             80  Comedy,Musical            nm0136068
# 1       2020             70           Drama  nm0749914,nm0765384
# 2       2010             80  Drama,Thriller            nm0863604
# 3       2018            122           Drama            nm0000080
# 4       2018             \N    Comedy,Drama            nm0611531
#
#                writers
# 0                   \N
# 1  nm0749914,nm1146177
# 2            nm0863604
# 3  nm0000080,nm0462648
# 4            nm0347899

# %%
dfMaster.set_index('directors')
# Out:
#                         tconst titleType  \
# directors
# nm0136068            tt0016906     movie
# nm0749914,nm0765384  tt0062336     movie
# nm0863604            tt0064322     movie
# nm0000080            tt0069049     movie
# nm0611531            tt0069204     movie
# ...                        ...       ...
# nm4457074            tt9916538     movie
# nm9272491,nm9272490  tt9916622     movie
# nm0652213            tt9916680     movie
# nm7764440            tt9916706     movie
# nm9272490,nm8349149  tt9916754     movie
#
#                                                          originalTitle  \
# directors
# nm0136068                                                   Frivolinas
# nm0749914,nm0765384          El tango del viudo y su espejo deformante
# nm0863604                                          La femme au couteau
# nm0000080                                   The Other Side of the Wind
# nm0611531                                              Sabse Bada Sukh
# ...                                                                ...
# nm4457074                                          Kuambil Lagi Hatiku
# nm9272491,nm9272490        Rodolpho Teóphilo - O Legado de um Pioneiro
# nm0652213            De la ilusión al desconcierto: cine colombiano...
# nm7764440                                              Dankyavar Danka
# nm9272490,nm8349149                     Chico Albuquerque - Revelações
#
#                      isAdult  startYear runtimeMinutes          genres  \
# directors
# nm0136068                  0       2014             80  Comedy,Musical
# nm0749914,nm0765384        0       2020             70           Drama
# nm0863604                  0       2010             80  Drama,Thriller
# nm0000080                  0       2018            122           Drama
# nm0611531                  0       2018             \N    Comedy,Drama
# ...                      ...        ...            ...             ...
# nm4457074                  0       2019            123           Drama
# nm9272491,nm9272490        0       2015             57     Documentary
# nm0652213                  0       2007            100     Documentary
# nm7764440                  0       2013             \N          Comedy
# nm9272490,nm8349149        0       2013             49     Documentary
#
#                                            writers
# directors
# nm0136068                                       \N
# nm0749914,nm0765384            nm0749914,nm1146177
# nm0863604                                nm0863604
# nm0000080                      nm0000080,nm0462648
# nm0611531                                nm0347899
# ...                                            ...
# nm4457074            nm4843252,nm4900525,nm2679404
# nm9272491,nm9272490            nm9272490,nm9272491
# nm0652213                     nm0652213,nm10538576
# nm7764440                                nm7933903
# nm9272490,nm8349149            nm8349149,nm9272490
#
# [200045 rows x 8 columns]

# %%
def splitDataFrameList(df,target_column,separator):
    ''' df = dataframe to split,
    target_column = the column containing the values to split
    separator = the symbol used to perform the split
    returns: a dataframe with each entry for the target column separated, with each element moved into a new row. 
    The values in the other columns are duplicated across the newly divided rows.
    '''
    def splitListToRows(row,row_accumulator,target_column,separator):
        split_row = row[target_column].split(separator)
        for s in split_row:
            new_row = row.to_dict()
            new_row[target_column] = s
            row_accumulator.append(new_row)
    new_rows = []
    df.apply(splitListToRows,axis=1,args = (new_rows,target_column,separator))
    new_df = pd.DataFrame(new_rows)
    return new_df
#code found https://gist.github.com/jlln/338b4b0b55bd6984f883 Thank you for the awesome function

# %%
dfMaster = dfMaster[(dfMaster['directors'] !=r'\N')]

# %%
dfMaster['directors'] = dfMaster.directors.astype('str', copy=False)

# %%
dfMaster = splitDataFrameList(dfMaster, 'directors', ',')

# %%
dfMaster.head()
# Out:
#       tconst titleType                              originalTitle  isAdult  \
# 0  tt0016906     movie                                 Frivolinas        0
# 1  tt0062336     movie  El tango del viudo y su espejo deformante        0
# 2  tt0062336     movie  El tango del viudo y su espejo deformante        0
# 3  tt0064322     movie                        La femme au couteau        0
# 4  tt0069049     movie                 The Other Side of the Wind        0
#
#    startYear runtimeMinutes          genres  directors              writers
# 0       2014             80  Comedy,Musical  nm0136068                   \N
# 1       2020             70           Drama  nm0749914  nm0749914,nm1146177
# 2       2020             70           Drama  nm0765384  nm0749914,nm1146177
# 3       2010             80  Drama,Thriller  nm0863604            nm0863604
# 4       2018            122           Drama  nm0000080  nm0000080,nm0462648

# %%
dfMaster = dfMaster[(dfMaster['writers'] !=r'\N')]

# %%
dfMaster.head()
# Out:
#       tconst titleType                              originalTitle  isAdult  \
# 1  tt0062336     movie  El tango del viudo y su espejo deformante        0
# 2  tt0062336     movie  El tango del viudo y su espejo deformante        0
# 3  tt0064322     movie                        La femme au couteau        0
# 4  tt0069049     movie                 The Other Side of the Wind        0
# 5  tt0069204     movie                            Sabse Bada Sukh        0
#
#    startYear runtimeMinutes          genres  directors              writers
# 1       2020             70           Drama  nm0749914  nm0749914,nm1146177
# 2       2020             70           Drama  nm0765384  nm0749914,nm1146177
# 3       2010             80  Drama,Thriller  nm0863604            nm0863604
# 4       2018            122           Drama  nm0000080  nm0000080,nm0462648
# 5       2018             \N    Comedy,Drama  nm0611531            nm0347899

# %%
dfMaster.dropna()
# Out:
#            tconst titleType  \
# 1       tt0062336     movie
# 2       tt0062336     movie
# 3       tt0064322     movie
# 4       tt0069049     movie
# 5       tt0069204     movie
# ...           ...       ...
# 226122  tt9916622     movie
# 226123  tt9916680     movie
# 226124  tt9916706     movie
# 226125  tt9916754     movie
# 226126  tt9916754     movie
#
#                                             originalTitle  isAdult  startYear  \
# 1               El tango del viudo y su espejo deformante        0       2020
# 2               El tango del viudo y su espejo deformante        0       2020
# 3                                     La femme au couteau        0       2010
# 4                              The Other Side of the Wind        0       2018
# 5                                         Sabse Bada Sukh        0       2018
# ...                                                   ...      ...        ...
# 226122        Rodolpho Teóphilo - O Legado de um Pioneiro        0       2015
# 226123  De la ilusión al desconcierto: cine colombiano...        0       2007
# 226124                                    Dankyavar Danka        0       2013
# 226125                     Chico Albuquerque - Revelações        0       2013
# 226126                     Chico Albuquerque - Revelações        0       2013
#
#        runtimeMinutes          genres  directors               writers
# 1                  70           Drama  nm0749914   nm0749914,nm1146177
# 2                  70           Drama  nm0765384   nm0749914,nm1146177
# 3                  80  Drama,Thriller  nm0863604             nm0863604
# 4                 122           Drama  nm0000080   nm0000080,nm0462648
# 5                  \N    Comedy,Drama  nm0611531             nm0347899
# ...               ...             ...        ...                   ...
# 226122             57     Documentary  nm9272490   nm9272490,nm9272491
# 226123            100     Documentary  nm0652213  nm0652213,nm10538576
# 226124             \N          Comedy  nm7764440             nm7933903
# 226125             49     Documentary  nm9272490   nm8349149,nm9272490
# 226126             49     Documentary  nm8349149   nm8349149,nm9272490
#
# [176423 rows x 9 columns]

# %%
dfMaster.head()
# Out:
#       tconst titleType                              originalTitle  isAdult  \
# 1  tt0062336     movie  El tango del viudo y su espejo deformante        0
# 2  tt0062336     movie  El tango del viudo y su espejo deformante        0
# 3  tt0064322     movie                        La femme au couteau        0
# 4  tt0069049     movie                 The Other Side of the Wind        0
# 5  tt0069204     movie                            Sabse Bada Sukh        0
#
#    startYear runtimeMinutes          genres  directors              writers
# 1       2020             70           Drama  nm0749914  nm0749914,nm1146177
# 2       2020             70           Drama  nm0765384  nm0749914,nm1146177
# 3       2010             80  Drama,Thriller  nm0863604            nm0863604
# 4       2018            122           Drama  nm0000080  nm0000080,nm0462648
# 5       2018             \N    Comedy,Drama  nm0611531            nm0347899

# %%
dfMaster['writers'] = dfMaster.writers.astype('str', copy=False)

# %%
dfMaster = splitDataFrameList(dfMaster, 'writers', ',')

# %%
dfMaster.head()
# Out:
#       tconst titleType                              originalTitle  isAdult  \
# 0  tt0062336     movie  El tango del viudo y su espejo deformante        0
# 1  tt0062336     movie  El tango del viudo y su espejo deformante        0
# 2  tt0062336     movie  El tango del viudo y su espejo deformante        0
# 3  tt0062336     movie  El tango del viudo y su espejo deformante        0
# 4  tt0064322     movie                        La femme au couteau        0
#
#    startYear runtimeMinutes          genres  directors    writers
# 0       2020             70           Drama  nm0749914  nm0749914
# 1       2020             70           Drama  nm0749914  nm1146177
# 2       2020             70           Drama  nm0765384  nm0749914
# 3       2020             70           Drama  nm0765384  nm1146177
# 4       2010             80  Drama,Thriller  nm0863604  nm0863604

# %%
dfNames.head()
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934        \N
# 3  nm0000004     John Belushi      1949      1982
# 4  nm0000005   Ingmar Bergman      1918      2007
#
#                 primaryProfession                           knownForTitles
# 0  soundtrack,actor,miscellaneous  tt0043044,tt0050419,tt0053137,tt0072308
# 1              actress,soundtrack  tt0037382,tt0038355,tt0117057,tt0071877
# 2     actress,soundtrack,producer  tt0054452,tt0059956,tt0057345,tt0049189
# 3         actor,soundtrack,writer  tt0078723,tt0080455,tt0077975,tt0072562
# 4           writer,director,actor  tt0050976,tt0083922,tt0060827,tt0050986

# %%
dfNames.set_index('nconst')
# Out:
#                   primaryName birthYear deathYear  \
# nconst
# nm0000001        Fred Astaire      1899      1987
# nm0000002       Lauren Bacall      1924      2014
# nm0000003     Brigitte Bardot      1934        \N
# nm0000004        John Belushi      1949      1982
# nm0000005      Ingmar Bergman      1918      2007
# ...                       ...       ...       ...
# nm9993714   Romeo del Rosario        \N        \N
# nm9993716       Essias Loberg        \N        \N
# nm9993717  Harikrishnan Rajan        \N        \N
# nm9993718         Aayush Nair        \N        \N
# nm9993719          Andre Hill        \N        \N
#
#                              primaryProfession  \
# nconst
# nm0000001       soundtrack,actor,miscellaneous
# nm0000002                   actress,soundtrack
# nm0000003          actress,soundtrack,producer
# nm0000004              actor,soundtrack,writer
# nm0000005                writer,director,actor
# ...                                        ...
# nm9993714  animation_department,art_department
# nm9993716                                  NaN
# nm9993717                      cinematographer
# nm9993718                      cinematographer
# nm9993719                                  NaN
#
#                                     knownForTitles
# nconst
# nm0000001  tt0043044,tt0050419,tt0053137,tt0072308
# nm0000002  tt0037382,tt0038355,tt0117057,tt0071877
# nm0000003  tt0054452,tt0059956,tt0057345,tt0049189
# nm0000004  tt0078723,tt0080455,tt0077975,tt0072562
# nm0000005  tt0050976,tt0083922,tt0060827,tt0050986
# ...                                            ...
# nm9993714                                tt2455546
# nm9993716                                       \N
# nm9993717                                tt8736744
# nm9993718                                       \N
# nm9993719                                       \N
#
# [10022860 rows x 5 columns]

# %%
dfNames.dropna()
# Out:
#              nconst         primaryName birthYear deathYear  \
# 0         nm0000001        Fred Astaire      1899      1987
# 1         nm0000002       Lauren Bacall      1924      2014
# 2         nm0000003     Brigitte Bardot      1934        \N
# 3         nm0000004        John Belushi      1949      1982
# 4         nm0000005      Ingmar Bergman      1918      2007
# ...             ...                 ...       ...       ...
# 10022850  nm9993709           Lu Bevins        \N        \N
# 10022854  nm9993713       Sambit Mishra        \N        \N
# 10022855  nm9993714   Romeo del Rosario        \N        \N
# 10022857  nm9993717  Harikrishnan Rajan        \N        \N
# 10022858  nm9993718         Aayush Nair        \N        \N
#
#                             primaryProfession  \
# 0              soundtrack,actor,miscellaneous
# 1                          actress,soundtrack
# 2                 actress,soundtrack,producer
# 3                     actor,soundtrack,writer
# 4                       writer,director,actor
# ...                                       ...
# 10022850      director,writer,cinematographer
# 10022854                               writer
# 10022855  animation_department,art_department
# 10022857                      cinematographer
# 10022858                      cinematographer
#
#                                        knownForTitles
# 0             tt0043044,tt0050419,tt0053137,tt0072308
# 1             tt0037382,tt0038355,tt0117057,tt0071877
# 2             tt0054452,tt0059956,tt0057345,tt0049189
# 3             tt0078723,tt0080455,tt0077975,tt0072562
# 4             tt0050976,tt0083922,tt0060827,tt0050986
# ...                                               ...
# 10022850  tt11772940,tt11772858,tt11702702,tt11772904
# 10022854                                    tt8325250
# 10022855                                    tt2455546
# 10022857                                    tt8736744
# 10022858                                           \N
#
# [7985286 rows x 6 columns]

# %%
dfNames = dfNames[(dfNames['knownForTitles'] !=r'\N')]

# %%
dfNames = dfNames[(dfNames['birthYear'] !=r'\N')]

# %%
dfNames = dfNames[(dfNames['deathYear'] !=r'\N')]

# %%
dfNames.set_index('nconst')
# Out:
#                  primaryName birthYear deathYear  \
# nconst
# nm0000001       Fred Astaire      1899      1987
# nm0000002      Lauren Bacall      1924      2014
# nm0000004       John Belushi      1949      1982
# nm0000005     Ingmar Bergman      1918      2007
# nm0000006     Ingrid Bergman      1915      1982
# ...                      ...       ...       ...
# nm9990008        Olavo Bilac      1865      1918
# nm9993432       Albert Minns      1920      1985
# nm9993434  Richard Blackmarr      1929      2013
# nm9993435       William Riva      1919      1999
# nm9993436     Frank J. Gaily      1915      2008
#
#                         primaryProfession  \
# nconst
# nm0000001  soundtrack,actor,miscellaneous
# nm0000002              actress,soundtrack
# nm0000004         actor,soundtrack,writer
# nm0000005           writer,director,actor
# nm0000006     actress,soundtrack,producer
# ...                                   ...
# nm9990008                          writer
# nm9993432                             NaN
# nm9993434                             NaN
# nm9993435                   set_decorator
# nm9993436                sound_department
#
#                                     knownForTitles
# nconst
# nm0000001  tt0043044,tt0050419,tt0053137,tt0072308
# nm0000002  tt0037382,tt0038355,tt0117057,tt0071877
# nm0000004  tt0078723,tt0080455,tt0077975,tt0072562
# nm0000005  tt0050976,tt0083922,tt0060827,tt0050986
# nm0000006  tt0038787,tt0038109,tt0034583,tt0036855
# ...                                            ...
# nm9990008                                tt8735938
# nm9993432                                tt0189339
# nm9993434                                tt0189339
# nm9993435                                tt0189339
# nm9993436                                tt0189339
#
# [162641 rows x 5 columns]

# %%
dfMaster.set_index('directors')
# Out:
#               tconst titleType                              originalTitle  \
# directors
# nm0749914  tt0062336     movie  El tango del viudo y su espejo deformante
# nm0749914  tt0062336     movie  El tango del viudo y su espejo deformante
# nm0765384  tt0062336     movie  El tango del viudo y su espejo deformante
# nm0765384  tt0062336     movie  El tango del viudo y su espejo deformante
# nm0863604  tt0064322     movie                        La femme au couteau
# ...              ...       ...                                        ...
# nm7764440  tt9916706     movie                            Dankyavar Danka
# nm9272490  tt9916754     movie             Chico Albuquerque - Revelações
# nm9272490  tt9916754     movie             Chico Albuquerque - Revelações
# nm8349149  tt9916754     movie             Chico Albuquerque - Revelações
# nm8349149  tt9916754     movie             Chico Albuquerque - Revelações
#
#            isAdult  startYear runtimeMinutes          genres    writers
# directors
# nm0749914        0       2020             70           Drama  nm0749914
# nm0749914        0       2020             70           Drama  nm1146177
# nm0765384        0       2020             70           Drama  nm0749914
# nm0765384        0       2020             70           Drama  nm1146177
# nm0863604        0       2010             80  Drama,Thriller  nm0863604
# ...            ...        ...            ...             ...        ...
# nm7764440        0       2013             \N          Comedy  nm7933903
# nm9272490        0       2013             49     Documentary  nm8349149
# nm9272490        0       2013             49     Documentary  nm9272490
# nm8349149        0       2013             49     Documentary  nm8349149
# nm8349149        0       2013             49     Documentary  nm9272490
#
# [350204 rows x 8 columns]

# %%
dfTest = dfMaster.join(dfNames,how='left')
# dfMaster = dfMaster.merge(dfWritersDir,on='tconst',how='left')

# %%
dfTest.head()
# Out:
#       tconst titleType                              originalTitle  isAdult  \
# 0  tt0062336     movie  El tango del viudo y su espejo deformante        0
# 1  tt0062336     movie  El tango del viudo y su espejo deformante        0
# 2  tt0062336     movie  El tango del viudo y su espejo deformante        0
# 3  tt0062336     movie  El tango del viudo y su espejo deformante        0
# 4  tt0064322     movie                        La femme au couteau        0
#
#    startYear runtimeMinutes          genres  directors    writers     nconst  \
# 0       2020             70           Drama  nm0749914  nm0749914  nm0000001
# 1       2020             70           Drama  nm0749914  nm1146177  nm0000002
# 2       2020             70           Drama  nm0765384  nm0749914        NaN
# 3       2020             70           Drama  nm0765384  nm1146177  nm0000004
# 4       2010             80  Drama,Thriller  nm0863604  nm0863604  nm0000005
#
#       primaryName birthYear deathYear               primaryProfession  \
# 0    Fred Astaire      1899      1987  soundtrack,actor,miscellaneous
# 1   Lauren Bacall      1924      2014              actress,soundtrack
# 2             NaN       NaN       NaN                             NaN
# 3    John Belushi      1949      1982         actor,soundtrack,writer
# 4  Ingmar Bergman      1918      2007           writer,director,actor
#
#                             knownForTitles
# 0  tt0043044,tt0050419,tt0053137,tt0072308
# 1  tt0037382,tt0038355,tt0117057,tt0071877
# 2                                      NaN
# 3  tt0078723,tt0080455,tt0077975,tt0072562
# 4  tt0050976,tt0083922,tt0060827,tt0050986

# %%
dfTest.tail()
# Out:
#            tconst titleType                   originalTitle  isAdult  \
# 350199  tt9916706     movie                 Dankyavar Danka        0
# 350200  tt9916754     movie  Chico Albuquerque - Revelações        0
# 350201  tt9916754     movie  Chico Albuquerque - Revelações        0
# 350202  tt9916754     movie  Chico Albuquerque - Revelações        0
# 350203  tt9916754     movie  Chico Albuquerque - Revelações        0
#
#         startYear runtimeMinutes       genres  directors    writers  \
# 350199       2013             \N       Comedy  nm7764440  nm7933903
# 350200       2013             49  Documentary  nm9272490  nm8349149
# 350201       2013             49  Documentary  nm9272490  nm9272490
# 350202       2013             49  Documentary  nm8349149  nm8349149
# 350203       2013             49  Documentary  nm8349149  nm9272490
#
#            nconst primaryName birthYear deathYear primaryProfession  \
# 350199        NaN         NaN       NaN       NaN               NaN
# 350200        NaN         NaN       NaN       NaN               NaN
# 350201        NaN         NaN       NaN       NaN               NaN
# 350202  nm0369260  Doris Haug      1927      2014     miscellaneous
# 350203        NaN         NaN       NaN       NaN               NaN
#
#        knownForTitles
# 350199            NaN
# 350200            NaN
# 350201            NaN
# 350202      tt0056913
# 350203            NaN

# %%
dfTest.dropna()
# Out:
#            tconst titleType                                originalTitle  \
# 0       tt0062336     movie    El tango del viudo y su espejo deformante
# 1       tt0062336     movie    El tango del viudo y su espejo deformante
# 3       tt0062336     movie    El tango del viudo y su espejo deformante
# 4       tt0064322     movie                          La femme au couteau
# 5       tt0069049     movie                   The Other Side of the Wind
# ...           ...       ...                                          ...
# 350169  tt9914286     movie                            Sokagin Çocuklari
# 350174  tt9914662     movie                  Wien is 't Hof van Commerce
# 350179  tt9914828     movie                          The War of Godzilla
# 350193  tt9916622     movie  Rodolpho Teóphilo - O Legado de um Pioneiro
# 350202  tt9916754     movie               Chico Albuquerque - Revelações
#
#         isAdult  startYear runtimeMinutes                genres   directors  \
# 0             0       2020             70                 Drama   nm0749914
# 1             0       2020             70                 Drama   nm0749914
# 3             0       2020             70                 Drama   nm0765384
# 4             0       2010             80        Drama,Thriller   nm0863604
# 5             0       2018            122                 Drama   nm0000080
# ...         ...        ...            ...                   ...         ...
# 350169        0       2019             98          Drama,Family   nm4394529
# 350174        0       2018             \N                Comedy  nm10537404
# 350179        0       2015            102  Action,Comedy,Family  nm10537549
# 350193        0       2015             57           Documentary   nm9272491
# 350202        0       2013             49           Documentary   nm8349149
#
#            writers     nconst         primaryName birthYear deathYear  \
# 0        nm0749914  nm0000001        Fred Astaire      1899      1987
# 1        nm1146177  nm0000002       Lauren Bacall      1924      2014
# 3        nm1146177  nm0000004        John Belushi      1949      1982
# 4        nm0863604  nm0000005      Ingmar Bergman      1918      2007
# 5        nm0000080  nm0000006      Ingrid Bergman      1915      1982
# ...            ...        ...                 ...       ...       ...
# 350169   nm1902682  nm0369224        Jochen Hauer      1899      1966
# 350174  nm10537404  nm0369229  Robert Hauer-Riedl      1942      2005
# 350179  nm10537598  nm0369234      Angelika Hauff      1922      1983
# 350193   nm9272490  nm0369250         Max Haufler      1910      1965
# 350202   nm8349149  nm0369260          Doris Haug      1927      2014
#
#                      primaryProfession  \
# 0       soundtrack,actor,miscellaneous
# 1                   actress,soundtrack
# 3              actor,soundtrack,writer
# 4                writer,director,actor
# 5          actress,soundtrack,producer
# ...                                ...
# 350169                           actor
# 350174                           actor
# 350179                         actress
# 350193           actor,director,writer
# 350202                   miscellaneous
#
#                                  knownForTitles
# 0       tt0043044,tt0050419,tt0053137,tt0072308
# 1       tt0037382,tt0038355,tt0117057,tt0071877
# 3       tt0078723,tt0080455,tt0077975,tt0072562
# 4       tt0050976,tt0083922,tt0060827,tt0050986
# 5       tt0038787,tt0038109,tt0034583,tt0036855
# ...                                         ...
# 350169  tt0026517,tt0027581,tt0140096,tt0044647
# 350174  tt0090554,tt0094784,tt0240794,tt0108829
# 350179  tt0044641,tt0158245,tt0037696,tt0317139
# 350193  tt0403271,tt0195057,tt0057427,tt0030118
# 350202                                tt0056913
#
# [43268 rows x 15 columns]

# %%
#from here we will join the table with the writers
dfMaster.to_csv('Master.csv', index=False)
